# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
#%pip install git+https://github.com/greydanus/mnist1d

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))

print("\n\n{}".format(data.keys()))

for key in list(data.keys()):
    if not isinstance(data[key], dict):
        print("\n{}: dimensions({})".format(str(key), data[key].shape))
    else:
        print("\n{}: dict".format(str(key)))

print(data['x'].shape)
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40
#
#
# dict_keys(['x', 'x_test', 'y', 'y_test', 't', 'templates'])
#
# x: dimensions((4000, 40))
#
# x_test: dimensions((1000, 40))
#
# y: dimensions((4000,))
#
# y_test: dimensions((1000,))
#
# t: dimensions((40,))
#
# templates: dict
# (4000, 40)

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(
  torch.nn.Linear(D_i, D_k),
  torch.nn.ReLU(),
  torch.nn.Linear(D_k, D_k),
  torch.nn.ReLU(),
  torch.nn.Linear(D_k, D_o),
  )


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  # print("Initializing layer")
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Call the function you just defined
model.apply(weights_init)
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_4756\1607323183.py:23: FutureWarning: `nn.init.kaiming_uniform` is now deprecated in favor of `nn.init.kaiming_uniform_`.
#   nn.init.kaiming_uniform(layer_in.weight)
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# C:\Users\David\AppData\Local\Temp\ipykernel_4756\1607323183.py:23: FutureWarning: `nn.init.kaiming_uniform` is now deprecated in favor of `nn.init.kaiming_uniform_`.
#   nn.init.kaiming_uniform(layer_in.weight)
# Epoch     0, train loss 1.573354, train error 61.95,  test loss 1.621511, test error 66.50
# Epoch     1, train loss 1.323425, train error 49.60,  test loss 1.428339, test error 56.30
# Epoch     2, train loss 1.166339, train error 43.28,  test loss 1.303033, test error 50.90
# Epoch     3, train loss 1.014982, train error 36.30,  test loss 1.194007, test error 46.00
# Epoch     4, train loss 0.890192, train error 31.72,  test loss 1.142795, test error 44.40
# Epoch     5, train loss 0.797909, train error 27.93,  test loss 1.096846, test error 42.30
# Epoch     6, train loss 0.712890, train error 25.60,  test loss 1.051231, test error 40.40
# Epoch     7, train loss 0.675832, train error 23.97,  test loss 1.068338, test error 40.10
# Epoch     8, train loss 0.592890, train error 20.38,  test loss 1.085784, test error 42.20
# Epoch     9, train loss 0.544653, train error 18.90,  test loss 1.130021, test error 42.00
# Epoch    10, train loss 0.432054, train error 13.75,  test loss 0.983614, test error 36.30
# Epoch    11, train loss 0.388680, train error 11.00,  test loss 0.995906, test error 38.10
# Epoch    12, train loss 0.360608, train error 10.38,  test loss 1.020467, test error 37.30
# Epoch    13, train loss 0.330707, train error 9.03,  test loss 1.046322, test error 37.90
# Epoch    14, train loss 0.305772, train error 8.22,  test loss 1.051541, test error 36.50
# Epoch    15, train loss 0.273666, train error 6.38,  test loss 1.069153, test error 36.30
# Epoch    16, train loss 0.258647, train error 5.88,  test loss 1.073736, test error 37.00
# Epoch    17, train loss 0.231196, train error 4.97,  test loss 1.094766, test error 37.60
# Epoch    18, train loss 0.222257, train error 5.03,  test loss 1.113505, test error 36.50
# Epoch    19, train loss 0.196701, train error 3.95,  test loss 1.114501, test error 36.30
# Epoch    20, train loss 0.169786, train error 2.57,  test loss 1.114887, test error 35.80
# Epoch    21, train loss 0.157997, train error 2.22,  test loss 1.129092, test error 36.80
# Epoch    22, train loss 0.145876, train error 1.62,  test loss 1.129053, test error 35.90
# Epoch    23, train loss 0.139021, train error 1.32,  test loss 1.150075, test error 36.10
# Epoch    24, train loss 0.132856, train error 1.18,  test loss 1.163055, test error 35.60
# Epoch    25, train loss 0.127905, train error 1.20,  test loss 1.178162, test error 36.50
# Epoch    26, train loss 0.120349, train error 0.78,  test loss 1.181283, test error 35.10
# Epoch    27, train loss 0.112707, train error 0.78,  test loss 1.176779, test error 35.60
# Epoch    28, train loss 0.108008, train error 0.60,  test loss 1.199239, test error 36.40
# Epoch    29, train loss 0.102283, train error 0.53,  test loss 1.195179, test error 35.50
# Epoch    30, train loss 0.097424, train error 0.30,  test loss 1.213884, test error 35.60
# Epoch    31, train loss 0.095375, train error 0.43,  test loss 1.221272, test error 35.40
# Epoch    32, train loss 0.092434, train error 0.32,  test loss 1.216476, test error 35.10
# Epoch    33, train loss 0.090480, train error 0.25,  test loss 1.225890, test error 35.00
# Epoch    34, train loss 0.088033, train error 0.22,  test loss 1.229801, test error 35.30
# Epoch    35, train loss 0.086053, train error 0.18,  test loss 1.236558, test error 35.70
# Epoch    36, train loss 0.084397, train error 0.20,  test loss 1.245542, test error 35.40
# Epoch    37, train loss 0.082101, train error 0.22,  test loss 1.247708, test error 35.40
# Epoch    38, train loss 0.080843, train error 0.22,  test loss 1.246560, test error 35.00
# Epoch    39, train loss 0.079169, train error 0.15,  test loss 1.254207, test error 35.80
# Epoch    40, train loss 0.077051, train error 0.20,  test loss 1.257622, test error 35.00
# Epoch    41, train loss 0.076149, train error 0.12,  test loss 1.261899, test error 34.90
# Epoch    42, train loss 0.075366, train error 0.15,  test loss 1.268345, test error 35.40
# Epoch    43, train loss 0.074378, train error 0.15,  test loss 1.267741, test error 35.40
# Epoch    44, train loss 0.073590, train error 0.18,  test loss 1.269337, test error 35.10
# Epoch    45, train loss 0.072845, train error 0.15,  test loss 1.274053, test error 35.60
# Epoch    46, train loss 0.071943, train error 0.12,  test loss 1.275552, test error 35.30
# Epoch    47, train loss 0.071282, train error 0.15,  test loss 1.277980, test error 35.10
# Epoch    48, train loss 0.070371, train error 0.12,  test loss 1.282309, test error 35.30
# Epoch    49, train loss 0.069880, train error 0.12,  test loss 1.284699, test error 35.30

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?

# %%
print(x_train.shape)
print(y_train.shape)

print(y_test.shape)

print(data['x'].shape)
print(data['y'].shape)
print(data['y'].transpose().shape)

print(data['y'].transpose())
print(data['y'])
# Out:
# torch.Size([4000, 40])
# torch.Size([4000])
# torch.Size([1000])
# (4000, 40)
# (4000,)
# (4000,)
# [2 6 4 ... 5 4 8]
# [2 6 4 ... 5 4 8]
